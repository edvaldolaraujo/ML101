# %% [markdown]
# # Modelos de Classificação

# %% [markdown]
# Carregando os dados

# %%
from sklearn import datasets
import numpy as np

# %%
iris = datasets.load_iris()
X = iris.data[:,[2,3]]
y = iris.target
print('Classes', np.unique(y))
# Out:
# Classes [0 1 2]

# %%
np.unique(y, return_counts=True)
# Out:
# (array([0, 1, 2]), array([50, 50, 50], dtype=int64))

# %% [markdown]
# Separando o conjunto de dados

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2021, stratify=y)

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1, 2]), array([35, 35, 35], dtype=int64))

# %%
print('Labels counts in y_test:', np.bincount(y_train))
# Out:
# Labels counts in y_test: [35 35 35]

# %% [markdown]
# Média dos dados

# %%
print('Média_1',X[:,0].mean())
print('Média_2',X[:,1].mean())
# Out:
# Média_1 3.7580000000000005
# Média_2 1.1993333333333336

# %% [markdown]
# Histograma

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(X[:,0], bins='auto')
# Out:
# (array([44.,  6.,  0.,  6., 17., 31., 21., 19.,  6.]),
#  array([1.        , 1.65555556, 2.31111111, 2.96666667, 3.62222222,
#         4.27777778, 4.93333333, 5.58888889, 6.24444444, 6.9       ]),
#  <BarContainer object of 9 artists>)

# %%
plt.boxplot(X[:,0])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x250907667c0>,
#   <matplotlib.lines.Line2D at 0x250906fa940>],
#  'caps': [<matplotlib.lines.Line2D at 0x25090749100>,
#   <matplotlib.lines.Line2D at 0x25090749fa0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x25090755370>],
#  'medians': [<matplotlib.lines.Line2D at 0x250906d44c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x250906d4d60>],
#  'means': []}

# %%
plt.hist(X[:,1], bins='auto')
# Out:
# (array([41.,  9.,  0., 10., 26., 18., 17., 15., 14.]),
#  array([0.1       , 0.36666667, 0.63333333, 0.9       , 1.16666667,
#         1.43333333, 1.7       , 1.96666667, 2.23333333, 2.5       ]),
#  <BarContainer object of 9 artists>)

# %%
plt.boxplot(X[:,1])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x250907549a0>,
#   <matplotlib.lines.Line2D at 0x25090754b50>],
#  'caps': [<matplotlib.lines.Line2D at 0x250906f9700>,
#   <matplotlib.lines.Line2D at 0x25090702d90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x250907a36a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x250906ebb80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x250906e23a0>],
#  'means': []}
